# %% [markdown]
# # 🦠 microbELP
#
# [![microbELP](https://img.shields.io/badge/GitHub-microbELP-181717?logo=github)](https://github.com/omicsNLP/microbELP)
#
#
# The notebook showcases our microbiome entity recognition (DL) module designed to automatically identify microbial mentions (bacteria, archaea, fungi) within scientific text.

# %% [markdown]
# # ⚙️ Installation
#
# MicrobELP has a number of dependencies on other Python packages; it is recommended to install it in an isolated environment.

# %%
# !git clone https://github.com/omicsNLP/microbELP.git

# %%
# !pip install ./microbELP

# %% [markdown]
# ## 🤖 Microbiome Entity Recognition (DL)

# %% [markdown]
# Here, I am quickly introducing our Deep Learning function for microbiome entity recognition. It can be used on both CPU and GPU. I am here using a notebook with no GPU. In the first run I am providing a string as input and on the second a list of strings. You can learn all about the parameters and output structure here: [![microbELP](https://img.shields.io/badge/GitHub-microbELP-181717?logo=github)](https://github.com/omicsNLP/microbELP/tree/main?tab=readme-ov-file#-microbiome-entity-recognition-dl).

# %%
from microbELP import microbiome_DL_ner

# %% [markdown]
# Running the code using a string.

# %%
entity_list = microbiome_DL_ner("The first microbiome I learned about is called Helicobacter pylori.")
# Out:
# GPU not detected, running the code using the CPU.

# %%
entity_list
# Out:
# [{'Entity': 'Helicobacter pylori', 'locations': {'offset': 47, 'length': 19}}]

# %%
entity_list[0]['Entity']
# Out:
# 'Helicobacter pylori'

# %%
entity_list[0]['locations']
# Out:
# {'offset': 47, 'length': 19}

# %% [markdown]
# Running the code using a list of strings.

# %%
microbiome_DL_ner([
                    "The first microbiome I learned about is called Helicobacter pylori.",
                    "Then I learned about Eubacterium rectale."
                  ]
                  )
# Out:
# GPU not detected, running the code using the CPU.
# [[{'Entity': 'Helicobacter pylori',
#    'locations': {'offset': 47, 'length': 19}}],
#  [{'Entity': 'Eubacterium rectale',
#    'locations': {'offset': 21, 'length': 19}}]]
